# %% [markdown]
# # Problem Statement:

# %% [raw]
# Flight ticket prices can be something hard to guess, today we might see a price, check out the price of the same flight tomorrow, it will be a different story. We might have often heard travellers saying that flight ticket prices are so unpredictable. Here you will be provided with prices of flight tickets for various airlines between the months of March and June of 2019 and between various cities.
#
# Size of training set: 10683 records
#
# Size of test set: 2671 records
#
# FEATURES:
# Airline: The name of the airline.
#
# Date_of_Journey: The date of the journey
#
# Source: The source from which the service begins.
#
# Destination: The destination where the service ends.
#
# Route: The route taken by the flight to reach the destination.
#
# Dep_Time: The time when the journey starts from the source.
#
# Arrival_Time: Time of arrival at the destination.
#
# Duration: Total duration of the flight.
#
# Total_Stops: Total stops between the source and destination.
#
# Additional_Info: Additional information about the flight
#
# Price: The price of the ticket

# %% [markdown]
# # Let's import required libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression,ElasticNet
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.ensemble import AdaBoostRegressor, BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor


from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # We will import the train_xls file for analysis now:

# %%
train=pd.read_excel(r"C:\Users\SAGAR KADAM\Downloads\Flight_Ticket_Participant_Datasets-20190305T100527Z-001\Flight_Ticket_Participant_Datasets\Data_Train.xlsx")
train=pd.DataFrame(data=train)
train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
train.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# Above is the list of all columns.

# %%
train.shape
# Out:
# (10683, 11)

# %% [markdown]
# Dataset has 10683 rows and 11 columns.

# %%
train.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# We can all columns except our target column(Price) are object type.

# %%
train.describe(include='all').T
# Out:
#                  count unique              top  freq     mean      std   min  \
# Airline          10683     12      Jet Airways  3849      NaN      NaN   NaN
# Date_of_Journey  10683     44       18/05/2019   504      NaN      NaN   NaN
# Source           10683      5            Delhi  4537      NaN      NaN   NaN
# Destination      10683      6           Cochin  4537      NaN      NaN   NaN
# Route            10682    128  DEL → BOM → COK  2376      NaN      NaN   NaN
# Dep_Time         10683    222            18:55   233      NaN      NaN   NaN
# Arrival_Time     10683   1343            19:00   423      NaN      NaN   NaN
# Duration         10683    368           2h 50m   550      NaN      NaN   NaN
# Total_Stops      10682      5           1 stop  5625      NaN      NaN   NaN
# Additional_Info  10683     10          No info  8345      NaN      NaN   NaN
# Price            10683    NaN              NaN   NaN  9087.06  4611.36  1759
#
#                   25%   50%    75%    max
# ...

# %% [markdown]
# # Outcome of describe of datasets:

# %% [raw]
# From the above plotting we are determining unique, top and freq for object type of column and mean, standard deviation, minimum and maximum value of numeric column. It helps us further in data Cleaning.
#
# Total number of rows in the datasets:
# 1.10683 rows
# 2.11 columns
#
# Airline:
# 1.unique=12
# 2.top=Jet Airways
# 3.freq=3849
#
# Date_of_Journey:
# 1.unique=44
# 2.top=18/05/2019
# 3.freq=504
#
# Source:
# 1.unique=5
# 2.top=Delhi
# 3.freq=4537
#
# Destination:
# 1.unique=6
# 2.top=Cochin
# 3.freq=4537
#
# Route:
# 1.unique=128
# 2.top=DEL → BOM → COK
# 3.freq=2376
#
# Dep_Time:
# 1.unique=222
# 2.top=18:55
# 3.freq=233
#
# Arrival_Time:
# 1.unique=1343
# 2.top=19.00
# 3.freq=423
#
# Duration:
# 1.unique=368
# 2.top=2h 50m
# 3.freq=550
#
# Total_Stops:
# 1.unique=5
# 2.top=1 stop
# 3.freq=5625
#
# Additional_Info:
# 1.unique=10
# 2.top=No info
# 3.freq=8345
#
# Price:
# 1.Mean=9087.06
# 2.Std=4611.36
# 3.min_value=1759
# 4.max_value=79512

# %%
train.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# We can see one null value in Route and Total_Stops column.

# %%
train.loc[train['Route'].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %% [markdown]
# Null values belongs to the same row for both the columns hence, we can drop the column.

# %%
train=train.dropna() #dropped null values

# %%
#Let's see it with the help of heatmap:
sns.heatmap(train.isnull())

# %%
train.nunique()
# Out:
# Airline              12
# Date_of_Journey      44
# Source                5
# Destination           6
# Route               128
# Dep_Time            222
# Arrival_Time       1343
# Duration            368
# Total_Stops           5
# Additional_Info      10
# Price              1870
# dtype: int64

# %% [raw]
# Also route column give us the info that flight had follow which path which gives us number of halts or stop and we have already have this info in 'Total_Stops' hence we can drop this column as well.

# %% [markdown]
# In Additional_Info columns we have 8345 time mentioned as no info hence, we can drop that column.

# %%
train.drop('Route', axis=1, inplace= True)
train.drop('Additional_Info', axis=1, inplace= True)
#dropped column Additional_Info and Total_Stops

# %% [markdown]
# Let's work on Total_Stops column first:

# %%
train['Total_Stops'].value_counts()
# Out:
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
#changing 'non-stop' to 0 as its a direct flight
train['Total_Stops'] = train['Total_Stops'].replace(to_replace='non-stop', value='0',regex=True)
#changing stops and stop to ''
train['Total_Stops'] = train['Total_Stops'].replace(to_replace='stops', value='',regex=True)
train['Total_Stops'] = train['Total_Stops'].replace(to_replace='stop', value='',regex=True)

# %%
train['Total_Stops'].value_counts()
# Out:
# 1     5625
# 0     3491
# 2     1520
# 3       45
# 4        1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# Let's work on Duration column now:

# %%
train['Duration'] = train['Duration'].replace(to_replace='h ', value='.',regex=True)
train['Duration'] = train['Duration'].str.replace('m', '')
#We have replaced 'h ' to . and m to nothing

# %%
train['Duration'] = train['Duration'].replace(to_replace='h', value='.',regex=True)
#now replaced h to .
train['Duration']=train['Duration'].str.strip()
#removing spaces from column as it was giving error while converting data to numberic

# %%
train['Duration']=pd.to_numeric(train['Duration'])

# %% [markdown]
# Let's work on which has time in it i.e. Dep_Time and Arrival_Time:

# %%
# Extract hours time from Dep_Time
train["Dep_hour"] = pd.to_datetime(train['Dep_Time']).dt.hour
train["Dep_min"] = pd.to_datetime(train['Dep_Time']).dt.minute

# Extract hours time from Arrival_Time
train["Arrival_hour"] = pd.to_datetime(train['Arrival_Time']).dt.hour
train["Arrival_min"] = pd.to_datetime(train['Arrival_Time']).dt.minute

#Now let's drop previous two columns
train.drop(['Dep_Time','Arrival_Time'], axis=1, inplace=True)

# %% [markdown]
# Let's work on Date_of_Journey column:

# %%
train['Journey_Date']=pd.to_datetime(train['Date_of_Journey'],format="%d/%m/%Y").dt.day
train['Journey_Month']=pd.to_datetime(train['Date_of_Journey'],format="%d/%m/%Y").dt.month

# %%
train.drop('Date_of_Journey',axis=1, inplace=True)

# %%
train
# Out:
#            Airline    Source Destination  Duration Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi      2.50           0   3897
# 1        Air India   Kolkata    Banglore      7.25          2    7662
# 2      Jet Airways     Delhi      Cochin     19.00          2   13882
# 3           IndiGo   Kolkata    Banglore      5.25          1    6218
# 4           IndiGo  Banglore   New Delhi      4.45          1   13302
# ...            ...       ...         ...       ...         ...    ...
# 10678     Air Asia   Kolkata    Banglore      2.30           0   4107
# 10679    Air India   Kolkata    Banglore      2.35           0   4145
# 10680  Jet Airways  Banglore       Delhi      3.00           0   7229
# 10681      Vistara  Banglore   New Delhi      2.40           0  12648
# 10682    Air India     Delhi      Cochin      8.20          2   11753
#
#        Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_Date  \
# ...

# %%
cat_col=[]
for i in train:
    if train.dtypes[i] == object:
        cat_col.append(i)
        
print(cat_col)
# Out:
# ['Airline', 'Source', 'Destination', 'Total_Stops']

# %%
for i in cat_col:
    plt.figure(figsize=(10,8))
    a=sns.countplot(train[i])
    print(train[i].value_counts())
    a.set_xticklabels(a.get_xticklabels(), rotation=90, ha="right")
    plt.show()
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64
# 1     5625
# 0     3491
# 2     1520
# 3       45
# 4        1
# Name: Total_Stops, dtype: int64

# %% [raw]
# Observations:
# 1. Maximum flights are of Jet Airways then we have IndiGo, Air India and Multiple carriers.
# 2. 4536 flights flied from Delhi, 2871 flied from Kolkata, 2197 flied from Banglore, From Mumbai 697 and lastly from Chennai 381.
# 3. 4536 flights arrived at Cochin, 2871 arrived at Banglore, 1295 flights arrived at Delhi, 932 arrived at New Delhi, 697 arrived at Hyderabad and lastly 381 arrived at Kolkata.
# 4. Maximum flight are with one stop i.e., 5625 flights, 3491 flight were direct, 1520 flights were with 2 stops, 45 flights with 3 stops and only flight had 4 stops.

# %%
for i in cat_col:
    plt.figure(figsize=(12,6))
    a=sns.lineplot(x=train[i],y=train['Price'],palette='Tableau')
    a.set_xticklabels(labels=train[i],rotation=90, ha="right")
    plt.show()

# %% [raw]
# Observations:
# 1. Highest price is for Airline SpiceJet.
# 2. Highest price charged was from source Delhi.
# 3. Highest price charged was for destination Banglore.
# 4. Highest price charged was for 1 stop flights.

# %%
plt.figure(figsize=(10,6))
a=sns.relplot(x='Airline',y='Price',hue='Source',data=train,kind='scatter')
a.set_xticklabels(labels=train['Airline'],rotation=90, ha="right")
plt.show()

# %% [markdown]
# Highest price charged was from banglore source and with Multiple carriers airlines.

# %%
plt.figure(figsize=(10,6))
a=sns.relplot(x='Airline',y='Price',hue='Destination',data=train,kind='scatter')
a.set_xticklabels(labels=train['Airline'],rotation=90, ha="right")
plt.show()

# %% [markdown]
# Highest price charged was for destination new delhi and with Multiple carriers airlines.

# %%
sns.relplot(x='Price', y='Total_Stops',data=train, kind='scatter')

# %% [markdown]
# For direct flight, price is ranging till around 33000. For one stop its ranging till 80000, for 2 stops its ranging till around 60000, for 3 stops its ranging till around 25000 and for 4 stops flight cost was around 20000

# %%
sns.relplot(x='Price', y='Duration',data=train, kind='scatter')

# %% [markdown]
# For duration from 0 to 40, usually price is ranging till 40000.

# %%
plt.figure(figsize=(10,6))
a=sns.relplot(x='Airline',y='Price',hue='Total_Stops',data=train,kind='scatter')
a.set_xticklabels(labels=train['Airline'],rotation=90, ha="right")
plt.show()

# %% [markdown]
# Highest price charged was for one stop flight and with Multiple carriers airlines.

# %%
plt.figure(figsize=(20,10))
for i in range(len(train.columns)):
    if train.dtypes[i] != 'object':
        plt.subplot(3,4,i+1)
        sns.distplot(train[train.columns[i]])

# %% [markdown]
# We can see uneven distribution of data in all columns.

# %%
plt.figure(figsize=(20,10))
for i in range(len(train.columns)):
    if train.dtypes[i] != 'object':
        plt.subplot(3,4,i+1)
        sns.boxplot(train[train.columns[i]])

# %% [markdown]
# We can see outliers in Duration and price column.

# %%
plt.figure(figsize=(8,8))
sns.heatmap(train.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# We can only see numerical column as all other columns are obejct type.
# Lets convert the data first.

# %% [markdown]
# # Encoding:

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

for i in train.columns:
    if train[i].dtypes=='object':
        train[i]=oe.fit_transform(train[i].values.astype(str).reshape(-1,1))

# %%
train
# Out:
#        Airline  Source  Destination  Duration  Total_Stops  Price  Dep_hour  \
# 0          3.0     0.0          5.0      2.50          0.0   3897        22
# 1          1.0     3.0          0.0      7.25          2.0   7662         5
# 2          4.0     2.0          1.0     19.00          2.0  13882         9
# 3          3.0     3.0          0.0      5.25          1.0   6218        18
# 4          3.0     0.0          5.0      4.45          1.0  13302        16
# ...        ...     ...          ...       ...          ...    ...       ...
# 10678      0.0     3.0          0.0      2.30          0.0   4107        19
# 10679      1.0     3.0          0.0      2.35          0.0   4145        20
# 10680      4.0     0.0          2.0      3.00          0.0   7229         8
# 10681     10.0     0.0          5.0      2.40          0.0  12648        11
# 10682      1.0     2.0          1.0      8.20          2.0  11753        10
#
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(train.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
cor_matrix=train.corr()
cor_matrix['Price'].sort_values(ascending=False)
# Out:
# Price            1.000000
# Total_Stops      0.603897
# Duration         0.508113
# Arrival_hour     0.024244
# Source           0.015999
# Dep_hour         0.006799
# Dep_min         -0.024458
# Airline         -0.039565
# Destination     -0.071122
# Arrival_min     -0.086155
# Journey_Month   -0.103643
# Journey_Date    -0.153774
# Name: Price, dtype: float64

# %% [markdown]
# Our target column Price is positively correlated with Total_Stops, Duration and has negative correlation with Journey_Date,Journey_Month and Arrival_min column.

# %%
sns.relplot(x='Journey_Date', y='Destination',data=train, kind='line')

# %% [markdown]
# We can see negative relation between Journey_Date and Destination.

# %%
sns.relplot(x='Source', y='Destination',data=train, kind='line')

# %% [markdown]
# We can see negative relation between Source and Destination.

# %%
sns.relplot(x='Duration', y='Total_Stops',data=train, kind='line')

# %% [markdown]
# For duration of maximum 5 hours we have direct flights, for duration of maximum 30 hours we have 2 stops flights and for duration of 30 to 40 hours of flight we have 3 & 4 hours of flights.

# %%
sns.pairplot(train)

# %% [markdown]
# # Skewness and outliers removal:

# %%
train.skew()
# Out:
# Airline          0.731057
# Source          -0.424023
# Destination      1.244046
# Duration         0.855125
# Total_Stops      0.317109
# Price            1.812405
# Dep_hour         0.112924
# Dep_min          0.167234
# Arrival_hour    -0.370146
# Arrival_min      0.110945
# Journey_Date     0.118174
# Journey_Month   -0.387409
# dtype: float64

# %% [raw]
# Keeping +/- 0.5 as the range for skewness.
# Below is the list columns which has skewness:
# Airline          Categorical
# Destination      Categorical
# Duration         Numeric
# Price            Target Column
#
# We dont consider skewness for categorical columns.

# %%
#removing outliers
from scipy.stats import zscore
z=np.abs(zscore(train))
z
# Out:
# array([[0.41080484, 1.65835945, 2.41653414, ..., 0.8900139 , 1.23728754,
#         1.46740227],
#        [1.26115217, 0.89001433, 0.97381203, ..., 0.5870944 , 1.47530729,
#         0.25028893],
#        [0.01436882, 0.04055641, 0.2957428 , ..., 0.0187446 , 0.53179604,
#         1.10913453],
#        ...,
#        [0.01436882, 1.65835945, 0.38232644, ..., 0.2841749 , 1.59110426,
#         0.60855667],
#        [2.56541078, 1.65835945, 2.41653414, ..., 0.8900139 , 1.47530729,
#         1.46740227],
#        [1.26115217, 0.04055641, 0.2957428 , ..., 0.5870944 , 0.53179604,
#         0.25028893]])

# %%
#threshold=3
print(np.where(z>3))
# Out:
# (array([  123,   226,   396,   402,   486,   510,   553,   597,   628,
#          657,   785,   826,   919,   936,   946,   959,   966,   969,
#          975,  1067,  1113,  1196,  1218,  1246,  1341,  1346,  1424,
#         1442,  1466,  1478,  1496,  1551,  1629,  1654,  1657,  1665,
#         1785,  1791,  1804,  1918,  2055,  2099,  2108,  2172,  2172,
#         2495,  2553,  2556,  2618,  2623,  2633,  2635,  2641,  2654,
#         2693,  2718,  2718,  2814,  2822,  2924,  3032,  3111,  3157,
#         3220,  3257,  3317,  3400,  3457,  3496,  3535,  3568,  3584,
#         3700,  3790,  3815,  3815,  3945,  3966,  4012,  4047,  4118,
#         4118,  4463,  4463,  4521,  4655,  4655,  4676,  4760,  4829,
#         5013,  5050,  5136,  5372,  5439,  5446,  5516,  5662,  5701,
#         5701,  5710,  5711,  5719,  5738,  5745,  5782,  5838,  5856,
#         5933,  5947,  5953,  5986,  5996,  6059,  6085,  6314,  6321,
# ...

# %%
train_new=train[(z<3).all(axis=1)] #removing outliers

# %%
train.shape
# Out:
# (10682, 12)

# %%
train_new.shape
# Out:
# (10488, 12)

# %%
#Percentage data loss:
loss_percent=(10682-10488)/10682*100
print(loss_percent)
# Out:
# 1.8161392997566002

# %%
x=train_new.drop('Price', axis=1)
y=train_new['Price']
print(x.shape)
print(y.shape)
# Out:
# (10488, 11)
# (10488,)

# %% [markdown]
# # Let's perform standardization:

# %%
from sklearn.preprocessing import MinMaxScaler
mmc=MinMaxScaler()
mmc.fit_transform(x)
# Out:
# array([[0.27272727, 0.        , 1.        , ..., 0.18181818, 0.88461538,
#         0.        ],
#        [0.09090909, 0.75      , 0.        , ..., 0.27272727, 0.        ,
#         0.66666667],
#        [0.36363636, 0.5       , 0.2       , ..., 0.45454545, 0.30769231,
#         1.        ],
#        ...,
#        [0.36363636, 0.        , 0.4       , ..., 0.36363636, 1.        ,
#         0.33333333],
#        [0.90909091, 0.        , 1.        , ..., 0.18181818, 0.        ,
#         0.        ],
#        [0.09090909, 0.5       , 0.2       , ..., 0.27272727, 0.30769231,
#         0.66666667]])

# %%
train_new=pd.DataFrame(train_new,columns=x.columns)
x=train_new

# %%
maxAcc=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    Ln=LinearRegression()
    Ln.fit(x_train,y_train)
    pred=Ln.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print("Best accuracy is ",maxAcc, " at Random State ",maxRS)
# Out:
# Best accuracy is  0.533272744896206  at Random State  132

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=maxRS)

# %%
model=[LinearRegression(),AdaBoostRegressor(),ElasticNet(alpha=0.0001),
       KNeighborsRegressor(),DecisionTreeRegressor(), BaggingRegressor()]
for m in model:
    m.fit(x_train,y_train)
    #sc=m.score(x_train,y_train)
    predm=m.predict(x_test)
    acc=r2_score(y_test,predm)
    print('Accuracy Score of',m,'is:',acc)
    print('mean_absolute_error:',mean_absolute_error(y_test,predm))
    print('mean_squared_error:',mean_squared_error(y_test,predm))
    print('Root mean_squared_error:',np.sqrt(mean_squared_error(y_test,predm)))
    print("\n")
# Out:
# Accuracy Score of LinearRegression() is: 0.533272744896206
# mean_absolute_error: 2172.9881616792304
# mean_squared_error: 7639783.822244651
# Root mean_squared_error: 2764.0158867569216
#
#
# Accuracy Score of AdaBoostRegressor() is: 0.6034834290863165
# mean_absolute_error: 2132.6903229663417
# mean_squared_error: 6490516.357448648
# Root mean_squared_error: 2547.6491825698154
#
#
# Accuracy Score of ElasticNet(alpha=0.0001) is: 0.5332664502356794
# mean_absolute_error: 2173.005136519085
# mean_squared_error: 7639886.858536472
# Root mean_squared_error: 2764.0345255688235
#
#
# Accuracy Score of KNeighborsRegressor() is: 0.7039609119609912
# mean_absolute_error: 1573.420591039085
# mean_squared_error: 4845816.50379409
# Root mean_squared_error: 2201.321535758484
#
#
# Accuracy Score of DecisionTreeRegressor() is: 0.7212416776589314
# mean_absolute_error: 1252.9274149984112
# mean_squared_error: 4562950.412792475
# Root mean_squared_error: 2136.1063673872786
#
#
# ...

# %% [raw]
# Accuracy for LinearRegression model is 53.33%
# Accuracy for AdaBoostRegressor model is 60.35%
# Accuracy for ElasticNet(alpha=0.0001) model is 53.33%
# Accuracy for KNeighborsRegressor model is 70.40%
# Accuracy for DecisionTreeRegressor model is 72.12%
# Accuracy for BaggingRegressor model is 80.17%

# %% [markdown]
# # Cross Validation of model:

# %%
model=[LinearRegression(),AdaBoostRegressor(),ElasticNet(alpha=0.0001),
       KNeighborsRegressor(),DecisionTreeRegressor(), BaggingRegressor()]
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print("Score for",m,"is: ",score.mean())
# Out:
# Score for LinearRegression() is:  0.5030835758014963
# Score for AdaBoostRegressor() is:  0.6062914165984167
# Score for ElasticNet(alpha=0.0001) is:  0.5030835565849394
# Score for KNeighborsRegressor() is:  0.6724213781859609
# Score for DecisionTreeRegressor() is:  0.7101904352473586
# Score for BaggingRegressor() is:  0.8004788427477605

# %% [markdown]
# With BaggingRegressor model there is very less difference in accuracy and cross validation score, Hence the best model is BaggingRegressor.

# %% [markdown]
# # Hyper Parameter Tunning:

# %%
from sklearn.model_selection import GridSearchCV

# %%
#Bagging
param={'base_estimator':[None],'n_estimators':[0,2,5,10],
      'bootstrap':[True,False],'oob_score':[True,False],'warm_start':[True,False],
       'bootstrap_features':[True,False],'random_state':range(0,20)}

# %%
GCV=GridSearchCV(BaggingRegressor(),param,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=BaggingRegressor(),
#              param_grid={'base_estimator': [None], 'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'n_estimators': [0, 2, 5, 10],
#                          'oob_score': [True, False],
#                          'random_state': range(0, 20),
#                          'warm_start': [True, False]})

# %%
GCV.best_params_
# Out:
# {'base_estimator': None,
#  'bootstrap': True,
#  'bootstrap_features': False,
#  'n_estimators': 10,
#  'oob_score': True,
#  'random_state': 3,
#  'warm_start': False}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)  
GCV_pred
# Out:
# array([11237.3  ,  7396.7  ,  8610.8  , ...,  9808.4  ,  6502.9  ,
#        10526.325])

# %%
r2_score(y_test,GCV_pred)
# Out:
# 0.8093188493832961

# %% [markdown]
# After performing GridSearchCV method accuarcy is 80.93%

# %% [markdown]
# # Saving best model:

# %%
#saving the model
import pickle
filename='GCVFlight.pkl'
pickle.dump(GCV,open(filename,'wb'))

# %% [markdown]
# # Using test dataset

# %%
test=pd.read_excel(r"C:\Users\SAGAR KADAM\Downloads\Flight_Ticket_Participant_Datasets-20190305T100527Z-001\Flight_Ticket_Participant_Datasets\Test_set.xlsx")
test=pd.DataFrame(data=test)
test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
test.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info'],
#       dtype='object')

# %% [markdown]
# Above is the list of all columns.

# %%
test.shape
# Out:
# (2671, 10)

# %% [markdown]
# Dataset has 2671 rows and 10 columns.

# %%
test.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# dtype: object

# %% [markdown]
# All columns are object type.

# %%
test.describe(include='all').T
# Out:
#                 count unique              top  freq
# Airline          2671     11      Jet Airways   897
# Date_of_Journey  2671     44        9/05/2019   144
# Source           2671      5            Delhi  1145
# Destination      2671      6           Cochin  1145
# Route            2671    100  DEL → BOM → COK   624
# Dep_Time         2671    199            10:00    62
# Arrival_Time     2671    704            19:00   113
# Duration         2671    320           2h 50m   122
# Total_Stops      2671      5           1 stop  1431
# Additional_Info  2671      6          No info  2148

# %% [markdown]
# # Outcome of describe of datasets:

# %% [raw]
# From the above plotting we are determining unique, top and freq for object type of column. It helps us further in data Cleaning.
#
# Total number of rows in the datasets:
# 1.2671 rows
# 2.10 columns
#
# Airline:
# 1.unique=11
# 2.top=Jet Airways
# 3.freq=897
#
# Date_of_Journey:
# 1.unique=44
# 2.top=9/05/2019
# 3.freq=144
#
# Source:
# 1.unique=5
# 2.top=Delhi
# 3.freq=1145
#
# Destination:
# 1.unique=6
# 2.top=Cochin
# 3.freq=1145
#
# Route:
# 1.unique=100
# 2.top=DEL → BOM → COK
# 3.freq=624
#
# Dep_Time:
# 1.unique=199
# 2.top=10:00
# 3.freq=62
#
# Arrival_Time:
# 1.unique=704
# 2.top=19:00
# 3.freq=113
#
# Duration:
# 1.unique=320
# 2.top=2h 50m
# 3.freq=122
#
# Total_Stops:
# 1.unique=5
# 2.top=1 stop
# 3.freq=1431
#
# Additional_Info:
# 1.unique=6
# 2.top=No info
# 3.freq=2148

# %%
test.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %%
#Let's see it with the help of heatmap:

# %%
sns.heatmap(test.isnull())

# %%
test.nunique()
# Out:
# Airline             11
# Date_of_Journey     44
# Source               5
# Destination          6
# Route              100
# Dep_Time           199
# Arrival_Time       704
# Duration           320
# Total_Stops          5
# Additional_Info      6
# dtype: int64

# %% [markdown]
# Also route column give us the info that flight had follow which path which gives us number of halts or stop and we have already have this info in 'Total_Stops' hence we can drop this column as well.
# In Additional_Info columns we have 2148 time mentioned as no info hence, we can drop that column.

# %%
test.drop('Route', axis=1, inplace= True)
test.drop('Additional_Info', axis=1, inplace= True)
#dropped column Additional_Info and Total_Stops

# %% [markdown]
# Let's work on Total_Stops column first:

# %%
test['Total_Stops'].value_counts()
# Out:
# 1 stop      1431
# non-stop     849
# 2 stops      379
# 3 stops       11
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
#changing 'non-stop' to 0 as its a direct flight
test['Total_Stops'] = test['Total_Stops'].replace(to_replace='non-stop', value='0',regex=True)
#changing stops and stop to ''
test['Total_Stops'] = test['Total_Stops'].replace(to_replace='stops', value='',regex=True)
test['Total_Stops'] = test['Total_Stops'].replace(to_replace='stop', value='',regex=True)

# %%
test['Total_Stops'].value_counts()
# Out:
# 1     1431
# 0      849
# 2      379
# 3       11
# 4        1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# Let's work on Duration column now:

# %%
test['Duration'] = test['Duration'].replace(to_replace='h ', value='.',regex=True)
test['Duration'] = test['Duration'].str.replace('m', '')
#We have replaced 'h ' to . and m to nothing

# %%
test['Duration'] = test['Duration'].replace(to_replace='h', value='.',regex=True)
#now replaced h to .
test['Duration']=test['Duration'].str.strip()
#removing spaces from column as it was giving error while converting data to numberic

# %%
test['Duration']=pd.to_numeric(test['Duration'])

# %% [markdown]
# Let's work on which has time in it i.e. Dep_Time and Arrival_Time:

# %%
# Extract hours time from Dep_Time
test["Dep_hour"] = pd.to_datetime(test['Dep_Time']).dt.hour
test["Dep_min"] = pd.to_datetime(test['Dep_Time']).dt.minute

# Extract hours time from Arrival_Time
test["Arrival_hour"] = pd.to_datetime(test['Arrival_Time']).dt.hour
test["Arrival_min"] = pd.to_datetime(test['Arrival_Time']).dt.minute

#Now let's drop previous two columns
test.drop(['Dep_Time','Arrival_Time'], axis=1, inplace=True)

# %% [markdown]
# Let's work on Date_of_Journey column:

# %%
test['Journey_Date']=pd.to_datetime(test['Date_of_Journey'],format="%d/%m/%Y").dt.day
test['Journey_month']=pd.to_datetime(test['Date_of_Journey'],format="%d/%m/%Y").dt.month

# %%
test.drop('Date_of_Journey',axis=1, inplace=True)

# %%
cat_col=[]
for i in test:
    if test.dtypes[i] == object:
        cat_col.append(i)
        
print(cat_col)
# Out:
# ['Airline', 'Source', 'Destination', 'Total_Stops']

# %%
for i in cat_col:
    plt.figure(figsize=(8,6))
    a=sns.countplot(test[i])
    print(test[i].value_counts())
    a.set_xticklabels(a.get_xticklabels(), rotation=90, ha="right")
    plt.show()
# Out:
# Jet Airways                          897
# IndiGo                               511
# Air India                            440
# Multiple carriers                    347
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 46
# Multiple carriers Premium economy      3
# Vistara Premium economy                2
# Jet Airways Business                   2
# Name: Airline, dtype: int64
# Delhi       1145
# Kolkata      710
# Banglore     555
# Mumbai       186
# Chennai       75
# Name: Source, dtype: int64
# Cochin       1145
# Banglore      710
# Delhi         317
# New Delhi     238
# Hyderabad     186
# Kolkata        75
# Name: Destination, dtype: int64
# 1     1431
# 0      849
# 2      379
# 3       11
# 4        1
# Name: Total_Stops, dtype: int64

# %% [raw]
# Observations:
# 1. Maximum flights are of Jet Airways then we have IndiGo, Air India and Multiple carriers.
# 2. 1145 flights flied from Delhi, 710 flied from Kolkata, 555 flied from Banglore, From Mumbai 186 and lastly from Chennai 75.
# 3. 1145 flights arrived at Cochin, 710 arrived at Banglore, 317 flights arrived at Delhi, 238 arrived at New Delhi, 186 arrived at Hyderabad and lastly 75 arrived at Kolkata.
# 4. Maximum flight are with one stop i.e., 1431 flights, 849 flight were direct, 379 flights were with 2 stops, 11 flights with 3 stops and only flight had 4 stops.

# %%
plt.figure(figsize=(20,10))
for i in range(len(test.columns)):
    if test.dtypes[i] != 'object':
        plt.subplot(3,4,i+1)
        sns.distplot(test[test.columns[i]])

# %% [markdown]
# We can see uneven distribution in all columns.

# %%
plt.figure(figsize=(20,10))
for i in range(len(test.columns)):
    if test.dtypes[i] != 'object':
        plt.subplot(3,4,i+1)
        sns.boxplot(test[test.columns[i]])

# %% [markdown]
# We have outliers in Duration column.

# %% [markdown]
# # Encoding:

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

for i in test.columns:
    if test[i].dtypes=='object':
        test[i]=oe.fit_transform(test[i].values.astype(str).reshape(-1,1))

# %%
plt.figure(figsize=(8,8))
sns.heatmap(test.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
sns.relplot(x='Journey_Date', y='Destination',data=test, kind='line')

# %% [markdown]
# We can see negative correlation between Journey data and Destination column.

# %%
sns.relplot(x='Source', y='Destination',data=test, kind='line')

# %% [markdown]
# We can see negative correlation between Source and Destination column.

# %%
sns.relplot(x='Duration', y='Total_Stops',data=test, kind='line')

# %% [markdown]
# For duration of maximum 5 hours we have direct flights, for duration of maximum 30 hours we have 2 stops flights and for duration of 30 to 40 hours of flight we have 3 & 4 hours of flights.

# %% [markdown]
# # Skewness and outliers removal:

# %%
test.skew()
# Out:
# Airline          0.483882
# Source          -0.424997
# Destination      1.263630
# Duration         0.889523
# Total_Stops      0.321364
# Dep_hour         0.093759
# Dep_min          0.128515
# Arrival_hour    -0.443166
# Arrival_min      0.115267
# Journey_Date     0.199540
# Journey_month   -0.403700
# dtype: float64

# %% [markdown]
# Keeping +/- 0.5 as the range for skewness however Except our target column all other columns were object type hence we will not consider the skewness.

# %%
#removing outliers
from scipy.stats import zscore
z=np.abs(zscore(test))
z
# Out:
# array([[0.01190758, 0.03256662, 0.29488167, ..., 0.02633999, 0.83733254,
#         1.09474457],
#        [0.42377921, 0.87708559, 0.97622158, ..., 0.27177067, 0.11087675,
#         0.2405048 ],
#        [0.01190758, 0.03256662, 0.29488167, ..., 1.46421332, 0.97880692,
#         0.2405048 ],
#        ...,
#        [0.01190758, 0.03256662, 0.29488167, ..., 0.02633999, 0.83733254,
#         1.46797475],
#        [1.29515278, 0.03256662, 0.29488167, ..., 0.56988133, 0.83733254,
#         1.46797475],
#        [0.88328115, 0.03256662, 0.29488167, ..., 0.56988133, 0.25235114,
#         1.09474457]])

# %%
#threshold=3
print(np.where(z>3))
# Out:
# (array([  72,  251,  251,  484,  510,  673,  725,  786,  875,  877, 1022,
#        1271, 1279, 1379, 1511, 1554, 1686, 1689, 1689, 1781, 1918, 1945,
#        2021, 2114, 2359, 2422, 2442, 2472, 2487, 2492], dtype=int64), array([4, 3, 4, 4, 3, 4, 4, 3, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3,
#        4, 3, 3, 4, 4, 3, 4, 3], dtype=int64))

# %%
test_new=test[(z<3).all(axis=1)] #removing outliers

# %%
test.shape
# Out:
# (2671, 11)

# %%
test_new.shape
# Out:
# (2643, 11)

# %%
#Percentage data loss:
loss_percent=(2671-2643)/2671*100
print(loss_percent)
# Out:
# 1.0482965181579933

# %% [markdown]
# # Lets perform standardization:

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit_transform(test_new)
# Out:
# array([[ 1.32187840e-03,  3.15505162e-02, -2.94978023e-01, ...,
#          2.82885423e-02, -8.38871378e-01,  1.08946063e+00],
#        [-4.35393698e-01,  8.73853692e-01, -9.76470083e-01, ...,
#         -2.69586427e-01, -1.11861742e-01,  2.32738094e-01],
#        [ 1.32187840e-03,  3.15505162e-02, -2.94978023e-01, ...,
#         -1.46108630e+00,  9.78652711e-01,  2.32738094e-01],
#        ...,
#        [ 1.32187840e-03,  3.15505162e-02, -2.94978023e-01, ...,
#          2.82885423e-02, -8.38871378e-01, -1.48070698e+00],
#        [-1.30882485e+00,  3.15505162e-02, -2.94978023e-01, ...,
#         -5.67461396e-01, -8.38871378e-01, -1.48070698e+00],
#        [ 8.74753032e-01,  3.15505162e-02, -2.94978023e-01, ...,
#         -5.67461396e-01,  2.51643075e-01,  1.08946063e+00]])

# %% [markdown]
# # load the model

# %%
fitted_model=pickle.load(open("GCVFlight.pkl","rb"))

# %%
fitted_model
# Out:
# GridSearchCV(cv=5, estimator=BaggingRegressor(),
#              param_grid={'base_estimator': [None], 'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'n_estimators': [0, 2, 5, 10],
#                          'oob_score': [True, False],
#                          'random_state': range(0, 20),
#                          'warm_start': [True, False]})

# %% [markdown]
# # prediction over test data

# %%
prediction=fitted_model.predict(test_new)

# %%
prediction=fitted_model.best_estimator_.predict(test_new)

# %%
prediction
# Out:
# array([12738.05,  4226.  , 14914.7 , ..., 14957.5 , 14396.9 ,  7472.7 ])
