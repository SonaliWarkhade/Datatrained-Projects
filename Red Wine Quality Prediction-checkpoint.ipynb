# %% [markdown]
# Problem Statement:
# The dataset is related to red and white variants of the Portuguese "Vinho Verde" wine. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# This dataset can be viewed as classification task. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.
#
# Attribute Information
#
# Input variables (based on physicochemical tests):
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
# Output variable (based on sensory data):
# 12 - quality (score between 0 and 10)
#
# What might be an interesting thing to do, is to set an arbitrary cutoff for your dependent variable (wine quality) at e.g. 7 or higher getting classified as 'good/1' and the remainder as 'not good/0'.
# This allows you to practice with hyper parameter tuning on e.g. decision tree algorithms looking at the ROC curve and the AUC value.
#
# You need to build a classification model.
#
# Inspiration
#
# Use machine learning to determine which physiochemical properties make a wine 'good'!

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer

from sklearn.model_selection import cross_val_score
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
cd=pd.read_csv('winequality-red.csv')
data=pd.DataFrame(data=cd)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [raw]
# Above is the list of all columns

# %%
data.shape
# Out:
# (1599, 12)

# %% [raw]
# dataset has 1599 row and 12 columns

# %%
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [raw]
# Datatypes of all attributes is numeric hence no need to perform encoding technique.

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # Outcome of describe of datasets:

# %% [raw]
# From the above plotting we are determining mean, standard deviation, minimum and maximum value of each column. It helps us further in data Cleaning.
#
# Total number of rows in the datasets:
# 1.1599 rows
# 2.12 columns
#
# fixed acidity:
# 1.Mean=8.3196
# 2.Std=1.7411
# 3.min_value=4.6000
# 4.max_value=15.9000
#
# volatile acidity:
# 1.Mean=0.5278
# 2.Std=0.1791
# 3.min_value=0.1200
# 4.max_value=1.5800
#
# citric acid:
# 1.Mean=0.2710
# 2.Std=0.1948
# 3.min_value=0.0000
# 4.max_value=1.0000
#
# residual sugar:
# 1.Mean=2.5388
# 2.Std=1.4099
# 3.max_value=0.9000
# 4.min_value=15.5000
#
# chlorides:
# 1.Mean=0.0875
# 2.Std=0.0471
# 3.min_value=0.0120
# 4.max_value=0.6110
#
# free sulfur dioxide:
# 1.Mean=15.8749
# 2.Std=10.4602
# 3.min_value=1.0000
# 4.max_value=72.0000
#
# total sulfur dioxide:
# 1.Mean=46.4678
# 2.Std=32.8953
# 3.min_value=6.0000
# 4.max_value=289.0000
#
# density:
# 1.Mean=0.9967
# 2.Std=0.0019
# 3.min_value=0.9901
# 4.max_value=1.0037
#
# pH:
# 1.Mean=3.3111
# 2.Std=0.1544
# 3.min_value=2.7400
# 4.max_value=4.0100
#
# sulphates:
# 1.Mean=0.6581
# 2.Std=0.1695
# 3.min_value=0.3300
# 4.max_value=2.0000
#
# alcohol:
# 1.Mean=10.4230
# 2.Std=1.0657
# 3.min_value=8.4000
# 4.max_value=14.9000

# %%
data.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %% [raw]
# Dataset has multiple unique values in each type of attribute.

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [raw]
# Dataset does not have any null values in it. Showing the same thing visualization technique:

# %%
sns.heatmap(data.isnull())

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [raw]
# Quality is positively correlated with alcohol and negatively correlated with volatile acidity

# %%
cor_matrix=data.corr()
cor_matrix['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %% [raw]
# Correlation with quality from highly positive to highly negative.

# %%
plt.scatter(data['alcohol'], data['quality'])

# %%
plt.scatter(data['volatile acidity'], data['quality'])

# %%
sns.countplot(x='quality',data=data)

# %% [raw]
# Above plot show the quality which ranges from  3 to 8, we have highest count with quality 5 then 6,7,4,8,3.

# %%
collist=data.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data[collist[i]],color='red',orient='v')
    plt.tight_layout()

# %% [raw]
# we can see there are continuous values after the 75th percentile(max value) those values cannot be consider as outlier as those are continuous not an odd value, however we have some outliers in total sulfur dioxide, some are in free sulfer dioxide.

# %%
data.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
for i in data.columns:
    plt.figure()
    sns.distplot(data[i])
    plt.show()

# %%
#removing outliers
from scipy.stats import zscore
z=np.abs(zscore(data))
z
# Out:
# array([[0.52835961, 0.96187667, 1.39147228, ..., 0.57920652, 0.96024611,
#         0.78782264],
#        [0.29854743, 1.96744245, 1.39147228, ..., 0.1289504 , 0.58477711,
#         0.78782264],
#        [0.29854743, 1.29706527, 1.18607043, ..., 0.04808883, 0.58477711,
#         0.78782264],
#        ...,
#        [1.1603431 , 0.09955388, 0.72391627, ..., 0.54204194, 0.54162988,
#         0.45084835],
#        [1.39015528, 0.65462046, 0.77526673, ..., 0.30598963, 0.20930812,
#         0.78782264],
#        [1.33270223, 1.21684919, 1.02199944, ..., 0.01092425, 0.54162988,
#         0.45084835]])

# %%
#threshold=4
print(np.where(z>4))
# Out:
# (array([  13,   17,   19,   33,   42,   81,   83,   86,   91,   92,  106,
#         126,  127,  151,  151,  169,  169,  226,  226,  258,  281,  291,
#         324,  325,  339,  396,  400,  442,  451,  480,  494,  554,  555,
#         557,  614,  639,  649,  652,  652,  692,  723,  730,  754,  911,
#         917,  923, 1043, 1051, 1051, 1079, 1079, 1081, 1081, 1165, 1235,
#        1244, 1244, 1260, 1299, 1316, 1319, 1321, 1370, 1372, 1434, 1435,
#        1474, 1476, 1558, 1574], dtype=int64), array([ 9,  4,  4,  3,  4,  4,  4,  9,  9,  9,  4,  1,  1,  4,  9,  4,  9,
#         4,  9,  4,  4,  4,  3,  3,  9,  5,  5,  0,  4,  3,  3,  0,  0,  0,
#         9,  9,  3,  0, 10,  4,  9,  4,  4,  3,  3,  3,  3,  4,  9,  3,  6,
#         3,  6,  4,  3,  3,  5,  4,  1,  8,  4,  8,  4,  4,  3,  3,  3,  3,
#         5,  3], dtype=int64))

# %%
data_new=data[(z<4).all(axis=1)] #removing outliers

# %%
data_new.shape
# Out:
# (1537, 12)

# %%
data.shape
# Out:
# (1599, 12)

# %%
#Percentage data loss:
loss_percent=(1599-1537)/1599*100
print(loss_percent)
# Out:
# 3.877423389618512

# %%
x=data_new.drop('quality', axis=1)
y=data_new['quality']
print(x.shape)
print(y.shape)
# Out:
# (1537, 11)
# (1537,)

# %%
from sklearn.preprocessing import power_transform
data_new=power_transform(x)

data_new=pd.DataFrame(data_new,columns=x.columns)

# %%
data_new.skew()
# Out:
# fixed acidity           0.006539
# volatile acidity        0.005435
# citric acid             0.017902
# residual sugar         -0.045022
# chlorides              -0.247571
# free sulfur dioxide    -0.014683
# total sulfur dioxide   -0.004977
# density                 0.005079
# pH                     -0.003207
# sulphates               0.021010
# alcohol                 0.110985
# dtype: float64

# %%
x=data_new

# %% [raw]
# Skewness has now been reduced.

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    DTC=DecisionTreeClassifier()
    DTC.fit(x_train,y_train)
    pred=DTC.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu, " on Random State ",maxRS)
# Out:
# Best accuracy is  0.698051948051948  on Random State  143

# %%
maxRS #best random state
# Out:
# 143

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=maxRS)

# %%
model=[DecisionTreeClassifier(),SVC(),AdaBoostClassifier()]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy Score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy Score of DecisionTreeClassifier() is:
# 0.6558441558441559
# [[ 0  0  0  1  0  0]
#  [ 0  1  2  2  1  0]
#  [ 3  5 99 13  4  0]
#  [ 1  2 32 81 16  2]
#  [ 0  0  4 11 21  3]
#  [ 0  0  1  2  1  0]]
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.12      0.17      0.14         6
#            5       0.72      0.80      0.76       124
#            6       0.74      0.60      0.66       134
#            7       0.49      0.54      0.51        39
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.66       308
#    macro avg       0.34      0.35      0.35       308
# weighted avg       0.67      0.66      0.66       308
#
#
#
# Accuracy Score of SVC() is:
# 0.6558441558441559
# [[  0   0   0   1   0   0]
#  [  0   0   4   2   0   0]
#  [  0   0 100  24   0   0]
#  [  0   0  38  90   6   0]
#  [  0   0   1  26  12   0]
# ...

# %% [raw]
# Accuracy for DecisionTreeClassifier is 66%, for SVC also its 66% and for AdaBoostClassifier its 59%

# %%
model=[DecisionTreeClassifier(),SVC(),AdaBoostClassifier()]
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print("Score for",m,"is :",score.mean())
# Out:
# Score for DecisionTreeClassifier() is : 0.4762045771817759
# Score for SVC() is : 0.5784424045010365
# Score for AdaBoostClassifier() is : 0.5387600998350184

# %% [raw]
# Best model is AdaBoostClassifier as there is very less differece model and cross validation compare to other models.

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'n_estimators':[50], 'learning_rate':[1.0], 'algorithm':['SAMME','SAMME.R'], 'random_state':[None]}

# %%
GCV=GridSearchCV(AdaBoostClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [1.0], 'n_estimators': [50],
#                          'random_state': [None]})

# %%
GCV.best_params_
# Out:
# {'algorithm': 'SAMME.R',
#  'learning_rate': 1.0,
#  'n_estimators': 50,
#  'random_state': None}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)

# %%
print(accuracy_score(y_test,GCV_pred))
# Out:
# 0.5876623376623377

# %% [raw]
# Accuracy has been improved from 53.87% to 58.76%

# %% [markdown]
# # Saving model

# %%
joblib.dump(GCV,"GCVwine.obj")
# Out:
# ['GCVwine.obj']

# %%
GCVfile=joblib.load("GCVwine.obj")
GCVfile.predict(x_train)
# Out:
# array([5, 6, 5, ..., 5, 6, 5], dtype=int64)
